# %% [markdown]
# # 3-Layer Neural Network for Non-linear Regression (TensorFlow High-Level API)
# In this notebook, we implement a 3-layer neural network using TensorFlow’s high-level Keras API, enabling a fully-managed and user-friendly approach to model building and training.
# This method emphasizes concise syntax, readability, and efficiency, making it ideal for rapid prototyping and experimentation.
#
# To ensure consistency across all implementations, we'll continue using the same synthetic 3-variable non-linear dataset.

# %%
# Import necessary libraries
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
import time

# Set random seed for reproducibility
tf.random.set_seed(42)
np.random.seed(42)

# Define the function to generate synthetic data
def true_function(X):
    """
    Non-linear function with 3 variables
    X should be a matrix with 3 columns
    """
    return 2 * tf.math.sin(X[:, 0]) + 3 * tf.math.cos(X[:, 1]) + 0.5 * X[:, 2]**2 + 0.1 * X[:, 0] * X[:, 1] * X[:, 2]

# Generate synthetic dataset
def generate_data(n_samples=1000):
    # Generate random inputs
    X = tf.cast(tf.random.uniform((n_samples, 3), -2, 2), tf.float32)

    # Calculate true output values
    y_true = true_function(X)

    # Add some noise
    y = y_true + tf.random.normal((n_samples,), 0, 0.5)

    return X, tf.reshape(y, (-1, 1))

# Generate training data
X_train, y_train = generate_data(1000)

# Generate test data
X_test, y_test = generate_data(200)

print(f"Training data shape: X = {X_train.shape}, y = {y_train.shape}")
print(f"Test data shape: X = {X_test.shape}, y = {y_test.shape}")
# Out:
# Training data shape: X = (1000, 3), y = (1000, 1)
# Test data shape: X = (200, 3), y = (200, 1)

# %% [markdown]
# ## Neural Network Implementation with TensorFlow High-Level API
# In this section, we’ll build a 3-layer neural network using TensorFlow’s high-level Keras API, which provides the most streamlined and intuitive way to define models.
# This approach emphasizes:
#
# Maximum simplicity and abstraction
#
# Minimal boilerplate code
#
# Easy integration with TensorFlow’s built-in training, evaluation, and visualization tools
#
# It's ideal for quickly developing and testing standard neural network architectures.

# %%
# Create model using the high-level Keras API
model = tf.keras.Sequential([
    tf.keras.layers.Dense(10, activation='relu', input_shape=(3,),
                         kernel_initializer=tf.keras.initializers.HeNormal()),
    tf.keras.layers.Dense(5, activation='relu',
                         kernel_initializer=tf.keras.initializers.HeNormal()),
    tf.keras.layers.Dense(1, activation=None,
                         kernel_initializer=tf.keras.initializers.HeNormal())
])

# Display model summary
model.summary()

# Compile the model
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.005),
    loss='mse',  # Mean Squared Error
    metrics=['mae']  # Mean Absolute Error as additional metric
)

# Define callbacks
callbacks = [
    tf.keras.callbacks.EarlyStopping(
        monitor='val_loss',
        patience=50,
        restore_best_weights=True
    ),
    tf.keras.callbacks.ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.5,
        patience=20,
        min_lr=0.0001
    ),
    tf.keras.callbacks.TensorBoard(
        log_dir='./logs',
        histogram_freq=1
    )
]

# Train the model with simple fit method
start_time = time.time()
history = model.fit(
    X_train, y_train,
    epochs=3000,
    batch_size=64,
    validation_data=(X_test, y_test),
    callbacks=callbacks,
    verbose=1
)
end_time = time.time()
print(f"Training completed in {end_time - start_time:.2f} seconds")
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 10)             │            40 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 5)              │            55 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │             6 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 101 (404.00 B)
#  Trainable params: 101 (404.00 B)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 57ms/step - loss: 4.9816 - mae: 1.7864 - val_loss: 3.7113 - val_mae: 1.5914 - learning_rate: 0.0050
# Epoch 2/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 3.3079 - mae: 1.4756 - val_loss: 2.7252 - val_mae: 1.3874 - learning_rate: 0.0050
# Epoch 3/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 2.4617 - mae: 1.2839 - val_loss: 2.1545 - val_mae: 1.2383 - learning_rate: 0.0050
# Epoch 4/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 1.9645 - mae: 1.1480 - val_loss: 1.7445 - val_mae: 1.1108 - learning_rate: 0.0050
# Epoch 5/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 1.5776 - mae: 1.0279 - val_loss: 1.3629 - val_mae: 0.9808 - learning_rate: 0.0050
# Epoch 6/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.2396 - mae: 0.9064 - val_loss: 1.0418 - val_mae: 0.8518 - learning_rate: 0.0050
# Epoch 7/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.9575 - mae: 0.7910 - val_loss: 0.8062 - val_mae: 0.7437 - learning_rate: 0.0050
# Epoch 8/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.7497 - mae: 0.6932 - val_loss: 0.6493 - val_mae: 0.6644 - learning_rate: 0.0050
# Epoch 9/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.6094 - mae: 0.6229 - val_loss: 0.5552 - val_mae: 0.6081 - learning_rate: 0.0050
# Epoch 10/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.5152 - mae: 0.5716 - val_loss: 0.4937 - val_mae: 0.5669 - learning_rate: 0.0050
# Epoch 11/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.4519 - mae: 0.5343 - val_loss: 0.4493 - val_mae: 0.5356 - learning_rate: 0.0050
# Epoch 12/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.4096 - mae: 0.5077 - val_loss: 0.4243 - val_mae: 0.5180 - learning_rate: 0.0050
# Epoch 13/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.3838 - mae: 0.4906 - val_loss: 0.4087 - val_mae: 0.5076 - learning_rate: 0.0050
# Epoch 14/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.3662 - mae: 0.4786 - val_loss: 0.3953 - val_mae: 0.4974 - learning_rate: 0.0050
# Epoch 15/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.3531 - mae: 0.4701 - val_loss: 0.3841 - val_mae: 0.4881 - learning_rate: 0.0050
# Epoch 16/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.3442 - mae: 0.4648 - val_loss: 0.3769 - val_mae: 0.4835 - learning_rate: 0.0050
# Epoch 17/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.3373 - mae: 0.4602 - val_loss: 0.3707 - val_mae: 0.4793 - learning_rate: 0.0050
# Epoch 18/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.3325 - mae: 0.4583 - val_loss: 0.3651 - val_mae: 0.4755 - learning_rate: 0.0050
# Epoch 19/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.3287 - mae: 0.4562 - val_loss: 0.3609 - val_mae: 0.4732 - learning_rate: 0.0050
# Epoch 20/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.3261 - mae: 0.4550 - val_loss: 0.3573 - val_mae: 0.4712 - learning_rate: 0.0050
# Epoch 21/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.3236 - mae: 0.4537 - val_loss: 0.3542 - val_mae: 0.4693 - learning_rate: 0.0050
# Epoch 22/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.3214 - mae: 0.4526 - val_loss: 0.3516 - val_mae: 0.4674 - learning_rate: 0.0050
# Epoch 23/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.3195 - mae: 0.4517 - val_loss: 0.3498 - val_mae: 0.4660 - learning_rate: 0.0050
# Epoch 24/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.3179 - mae: 0.4514 - val_loss: 0.3484 - val_mae: 0.4653 - learning_rate: 0.0050
# Epoch 25/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.3152 - mae: 0.4501 - val_loss: 0.3480 - val_mae: 0.4654 - learning_rate: 0.0050
# Epoch 26/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.3138 - mae: 0.4497 - val_loss: 0.3467 - val_mae: 0.4646 - learning_rate: 0.0050
# Epoch 27/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.3120 - mae: 0.4489 - val_loss: 0.3457 - val_mae: 0.4640 - learning_rate: 0.0050
# Epoch 28/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.3108 - mae: 0.4484 - val_loss: 0.3452 - val_mae: 0.4638 - learning_rate: 0.0050
# Epoch 29/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.3090 - mae: 0.4473 - val_loss: 0.3447 - val_mae: 0.4636 - learning_rate: 0.0050
# Epoch 30/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.3073 - mae: 0.4465 - val_loss: 0.3445 - val_mae: 0.4634 - learning_rate: 0.0050
# Epoch 31/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.3062 - mae: 0.4460 - val_loss: 0.3442 - val_mae: 0.4628 - learning_rate: 0.0050
# Epoch 32/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.3053 - mae: 0.4457 - val_loss: 0.3441 - val_mae: 0.4629 - learning_rate: 0.0050
# Epoch 33/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.3041 - mae: 0.4449 - val_loss: 0.3435 - val_mae: 0.4625 - learning_rate: 0.0050
# Epoch 34/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.3026 - mae: 0.4440 - val_loss: 0.3438 - val_mae: 0.4628 - learning_rate: 0.0050
# Epoch 35/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.3014 - mae: 0.4432 - val_loss: 0.3439 - val_mae: 0.4626 - learning_rate: 0.0050
# Epoch 36/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.3002 - mae: 0.4425 - val_loss: 0.3438 - val_mae: 0.4624 - learning_rate: 0.0050
# Epoch 37/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2991 - mae: 0.4418 - val_loss: 0.3437 - val_mae: 0.4622 - learning_rate: 0.0050
# Epoch 38/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2982 - mae: 0.4414 - val_loss: 0.3434 - val_mae: 0.4618 - learning_rate: 0.0050
# Epoch 39/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.2973 - mae: 0.4407 - val_loss: 0.3425 - val_mae: 0.4612 - learning_rate: 0.0050
# Epoch 40/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2969 - mae: 0.4405 - val_loss: 0.3425 - val_mae: 0.4613 - learning_rate: 0.0050
# Epoch 41/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2962 - mae: 0.4398 - val_loss: 0.3427 - val_mae: 0.4614 - learning_rate: 0.0050
# Epoch 42/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2959 - mae: 0.4396 - val_loss: 0.3427 - val_mae: 0.4617 - learning_rate: 0.0050
# Epoch 43/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2954 - mae: 0.4392 - val_loss: 0.3419 - val_mae: 0.4612 - learning_rate: 0.0050
# Epoch 44/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2948 - mae: 0.4389 - val_loss: 0.3414 - val_mae: 0.4610 - learning_rate: 0.0050
# Epoch 45/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.2944 - mae: 0.4384 - val_loss: 0.3412 - val_mae: 0.4608 - learning_rate: 0.0050
# Epoch 46/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.2938 - mae: 0.4378 - val_loss: 0.3412 - val_mae: 0.4608 - learning_rate: 0.0050
# Epoch 47/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.2933 - mae: 0.4373 - val_loss: 0.3413 - val_mae: 0.4607 - learning_rate: 0.0050
# Epoch 48/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.2928 - mae: 0.4368 - val_loss: 0.3408 - val_mae: 0.4606 - learning_rate: 0.0050
# Epoch 49/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.2918 - mae: 0.4358 - val_loss: 0.3399 - val_mae: 0.4600 - learning_rate: 0.0050
# Epoch 50/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.2913 - mae: 0.4356 - val_loss: 0.3389 - val_mae: 0.4592 - learning_rate: 0.0050
# Epoch 51/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2903 - mae: 0.4347 - val_loss: 0.3383 - val_mae: 0.4584 - learning_rate: 0.0050
# Epoch 52/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2902 - mae: 0.4346 - val_loss: 0.3387 - val_mae: 0.4589 - learning_rate: 0.0050
# Epoch 53/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2894 - mae: 0.4339 - val_loss: 0.3386 - val_mae: 0.4587 - learning_rate: 0.0050
# Epoch 54/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2891 - mae: 0.4337 - val_loss: 0.3382 - val_mae: 0.4583 - learning_rate: 0.0050
# Epoch 55/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2885 - mae: 0.4333 - val_loss: 0.3382 - val_mae: 0.4582 - learning_rate: 0.0050
# Epoch 56/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2878 - mae: 0.4327 - val_loss: 0.3385 - val_mae: 0.4581 - learning_rate: 0.0050
# Epoch 57/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2874 - mae: 0.4325 - val_loss: 0.3389 - val_mae: 0.4582 - learning_rate: 0.0050
# Epoch 58/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.2867 - mae: 0.4320 - val_loss: 0.3389 - val_mae: 0.4579 - learning_rate: 0.0050
# Epoch 59/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2864 - mae: 0.4318 - val_loss: 0.3393 - val_mae: 0.4579 - learning_rate: 0.0050
# Epoch 60/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2859 - mae: 0.4315 - val_loss: 0.3396 - val_mae: 0.4578 - learning_rate: 0.0050
# Epoch 61/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2854 - mae: 0.4313 - val_loss: 0.3391 - val_mae: 0.4574 - learning_rate: 0.0050
# Epoch 62/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2849 - mae: 0.4309 - val_loss: 0.3385 - val_mae: 0.4568 - learning_rate: 0.0050
# Epoch 63/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.2844 - mae: 0.4306 - val_loss: 0.3384 - val_mae: 0.4567 - learning_rate: 0.0050
# Epoch 64/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2840 - mae: 0.4304 - val_loss: 0.3385 - val_mae: 0.4566 - learning_rate: 0.0050
# Epoch 65/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2838 - mae: 0.4302 - val_loss: 0.3380 - val_mae: 0.4563 - learning_rate: 0.0050
# Epoch 66/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2832 - mae: 0.4298 - val_loss: 0.3378 - val_mae: 0.4561 - learning_rate: 0.0050
# Epoch 67/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2830 - mae: 0.4295 - val_loss: 0.3376 - val_mae: 0.4562 - learning_rate: 0.0050
# Epoch 68/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2826 - mae: 0.4291 - val_loss: 0.3380 - val_mae: 0.4563 - learning_rate: 0.0050
# Epoch 69/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2822 - mae: 0.4287 - val_loss: 0.3380 - val_mae: 0.4566 - learning_rate: 0.0050
# Epoch 70/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2816 - mae: 0.4283 - val_loss: 0.3375 - val_mae: 0.4561 - learning_rate: 0.0050
# Epoch 71/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2813 - mae: 0.4281 - val_loss: 0.3370 - val_mae: 0.4558 - learning_rate: 0.0050
# Epoch 72/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2807 - mae: 0.4277 - val_loss: 0.3364 - val_mae: 0.4555 - learning_rate: 0.0050
# Epoch 73/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2801 - mae: 0.4274 - val_loss: 0.3364 - val_mae: 0.4556 - learning_rate: 0.0050
# Epoch 74/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2796 - mae: 0.4271 - val_loss: 0.3366 - val_mae: 0.4558 - learning_rate: 0.0050
# Epoch 75/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2794 - mae: 0.4270 - val_loss: 0.3368 - val_mae: 0.4559 - learning_rate: 0.0050
# Epoch 76/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2791 - mae: 0.4268 - val_loss: 0.3367 - val_mae: 0.4557 - learning_rate: 0.0050
# Epoch 77/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2789 - mae: 0.4267 - val_loss: 0.3371 - val_mae: 0.4561 - learning_rate: 0.0050
# Epoch 78/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2788 - mae: 0.4268 - val_loss: 0.3372 - val_mae: 0.4559 - learning_rate: 0.0050
# Epoch 79/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.2784 - mae: 0.4265 - val_loss: 0.3367 - val_mae: 0.4553 - learning_rate: 0.0050
# Epoch 80/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.2786 - mae: 0.4266 - val_loss: 0.3377 - val_mae: 0.4559 - learning_rate: 0.0050
# Epoch 81/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.2785 - mae: 0.4265 - val_loss: 0.3375 - val_mae: 0.4556 - learning_rate: 0.0050
# Epoch 82/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2781 - mae: 0.4263 - val_loss: 0.3370 - val_mae: 0.4551 - learning_rate: 0.0050
# Epoch 83/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2782 - mae: 0.4263 - val_loss: 0.3374 - val_mae: 0.4555 - learning_rate: 0.0050
# Epoch 84/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2778 - mae: 0.4260 - val_loss: 0.3374 - val_mae: 0.4554 - learning_rate: 0.0050
# Epoch 85/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2777 - mae: 0.4260 - val_loss: 0.3374 - val_mae: 0.4552 - learning_rate: 0.0050
# Epoch 86/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.2776 - mae: 0.4259 - val_loss: 0.3374 - val_mae: 0.4554 - learning_rate: 0.0050
# Epoch 87/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.2773 - mae: 0.4256 - val_loss: 0.3377 - val_mae: 0.4556 - learning_rate: 0.0050
# Epoch 88/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.2770 - mae: 0.4254 - val_loss: 0.3376 - val_mae: 0.4554 - learning_rate: 0.0050
# Epoch 89/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.2768 - mae: 0.4252 - val_loss: 0.3370 - val_mae: 0.4552 - learning_rate: 0.0050
# Epoch 90/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.2764 - mae: 0.4248 - val_loss: 0.3372 - val_mae: 0.4552 - learning_rate: 0.0050
# Epoch 91/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.2758 - mae: 0.4244 - val_loss: 0.3365 - val_mae: 0.4548 - learning_rate: 0.0050
# Epoch 92/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.2756 - mae: 0.4241 - val_loss: 0.3353 - val_mae: 0.4539 - learning_rate: 0.0050
# Epoch 93/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2757 - mae: 0.4239 - val_loss: 0.3345 - val_mae: 0.4531 - learning_rate: 0.0050
# Epoch 94/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2754 - mae: 0.4236 - val_loss: 0.3337 - val_mae: 0.4527 - learning_rate: 0.0050
# Epoch 95/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2753 - mae: 0.4235 - val_loss: 0.3343 - val_mae: 0.4529 - learning_rate: 0.0050
# Epoch 96/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2752 - mae: 0.4234 - val_loss: 0.3337 - val_mae: 0.4524 - learning_rate: 0.0050
# Epoch 97/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2754 - mae: 0.4233 - val_loss: 0.3340 - val_mae: 0.4526 - learning_rate: 0.0050
# Epoch 98/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2747 - mae: 0.4228 - val_loss: 0.3342 - val_mae: 0.4526 - learning_rate: 0.0050
# Epoch 99/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2747 - mae: 0.4229 - val_loss: 0.3344 - val_mae: 0.4526 - learning_rate: 0.0050
# Epoch 100/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2749 - mae: 0.4230 - val_loss: 0.3339 - val_mae: 0.4521 - learning_rate: 0.0050
# Epoch 101/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2743 - mae: 0.4225 - val_loss: 0.3333 - val_mae: 0.4516 - learning_rate: 0.0050
# Epoch 102/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2742 - mae: 0.4223 - val_loss: 0.3334 - val_mae: 0.4515 - learning_rate: 0.0050
# Epoch 103/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2740 - mae: 0.4220 - val_loss: 0.3329 - val_mae: 0.4512 - learning_rate: 0.0050
# Epoch 104/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2738 - mae: 0.4218 - val_loss: 0.3328 - val_mae: 0.4511 - learning_rate: 0.0050
# Epoch 105/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2736 - mae: 0.4215 - val_loss: 0.3325 - val_mae: 0.4510 - learning_rate: 0.0050
# Epoch 106/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2734 - mae: 0.4213 - val_loss: 0.3323 - val_mae: 0.4508 - learning_rate: 0.0050
# Epoch 107/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2731 - mae: 0.4211 - val_loss: 0.3329 - val_mae: 0.4513 - learning_rate: 0.0050
# Epoch 108/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.2731 - mae: 0.4211 - val_loss: 0.3328 - val_mae: 0.4511 - learning_rate: 0.0050
# Epoch 109/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.2729 - mae: 0.4208 - val_loss: 0.3332 - val_mae: 0.4515 - learning_rate: 0.0050
# Epoch 110/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2725 - mae: 0.4205 - val_loss: 0.3333 - val_mae: 0.4516 - learning_rate: 0.0050
# Epoch 111/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2727 - mae: 0.4206 - val_loss: 0.3330 - val_mae: 0.4514 - learning_rate: 0.0050
# Epoch 112/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2726 - mae: 0.4204 - val_loss: 0.3329 - val_mae: 0.4514 - learning_rate: 0.0050
# Epoch 113/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2721 - mae: 0.4201 - val_loss: 0.3330 - val_mae: 0.4514 - learning_rate: 0.0050
# Epoch 114/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2724 - mae: 0.4203 - val_loss: 0.3326 - val_mae: 0.4511 - learning_rate: 0.0050
# Epoch 115/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2720 - mae: 0.4199 - val_loss: 0.3320 - val_mae: 0.4506 - learning_rate: 0.0050
# Epoch 116/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2721 - mae: 0.4199 - val_loss: 0.3317 - val_mae: 0.4505 - learning_rate: 0.0050
# Epoch 117/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2719 - mae: 0.4197 - val_loss: 0.3318 - val_mae: 0.4504 - learning_rate: 0.0050
# Epoch 118/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2717 - mae: 0.4194 - val_loss: 0.3316 - val_mae: 0.4503 - learning_rate: 0.0050
# Epoch 119/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2718 - mae: 0.4195 - val_loss: 0.3316 - val_mae: 0.4502 - learning_rate: 0.0050
# Epoch 120/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2717 - mae: 0.4193 - val_loss: 0.3313 - val_mae: 0.4500 - learning_rate: 0.0050
# Epoch 121/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2716 - mae: 0.4192 - val_loss: 0.3311 - val_mae: 0.4496 - learning_rate: 0.0050
# Epoch 122/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2715 - mae: 0.4191 - val_loss: 0.3313 - val_mae: 0.4498 - learning_rate: 0.0050
# Epoch 123/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2713 - mae: 0.4189 - val_loss: 0.3308 - val_mae: 0.4495 - learning_rate: 0.0050
# Epoch 124/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2716 - mae: 0.4191 - val_loss: 0.3312 - val_mae: 0.4497 - learning_rate: 0.0050
# Epoch 125/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2713 - mae: 0.4187 - val_loss: 0.3308 - val_mae: 0.4495 - learning_rate: 0.0050
# Epoch 126/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2712 - mae: 0.4187 - val_loss: 0.3310 - val_mae: 0.4498 - learning_rate: 0.0050
# Epoch 127/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2713 - mae: 0.4187 - val_loss: 0.3310 - val_mae: 0.4495 - learning_rate: 0.0050
# Epoch 128/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2709 - mae: 0.4183 - val_loss: 0.3309 - val_mae: 0.4494 - learning_rate: 0.0050
# Epoch 129/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2711 - mae: 0.4186 - val_loss: 0.3316 - val_mae: 0.4497 - learning_rate: 0.0050
# Epoch 130/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.2707 - mae: 0.4182 - val_loss: 0.3310 - val_mae: 0.4492 - learning_rate: 0.0050
# Epoch 131/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.2707 - mae: 0.4181 - val_loss: 0.3314 - val_mae: 0.4496 - learning_rate: 0.0050
# Epoch 132/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.2703 - mae: 0.4178 - val_loss: 0.3310 - val_mae: 0.4492 - learning_rate: 0.0050
# Epoch 133/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.2703 - mae: 0.4178 - val_loss: 0.3313 - val_mae: 0.4495 - learning_rate: 0.0050
# Epoch 134/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.2703 - mae: 0.4177 - val_loss: 0.3305 - val_mae: 0.4490 - learning_rate: 0.0050
# Epoch 135/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.2701 - mae: 0.4175 - val_loss: 0.3311 - val_mae: 0.4493 - learning_rate: 0.0050
# Epoch 136/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.2698 - mae: 0.4173 - val_loss: 0.3306 - val_mae: 0.4491 - learning_rate: 0.0050
# Epoch 137/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2700 - mae: 0.4174 - val_loss: 0.3312 - val_mae: 0.4496 - learning_rate: 0.0050
# Epoch 138/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2697 - mae: 0.4171 - val_loss: 0.3308 - val_mae: 0.4491 - learning_rate: 0.0050
# Epoch 139/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2698 - mae: 0.4171 - val_loss: 0.3308 - val_mae: 0.4493 - learning_rate: 0.0050
# Epoch 140/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2694 - mae: 0.4169 - val_loss: 0.3305 - val_mae: 0.4489 - learning_rate: 0.0050
# Epoch 141/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2696 - mae: 0.4170 - val_loss: 0.3307 - val_mae: 0.4493 - learning_rate: 0.0050
# Epoch 142/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2692 - mae: 0.4167 - val_loss: 0.3310 - val_mae: 0.4495 - learning_rate: 0.0050
# Epoch 143/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2696 - mae: 0.4170 - val_loss: 0.3307 - val_mae: 0.4491 - learning_rate: 0.0050
# Epoch 144/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2693 - mae: 0.4167 - val_loss: 0.3301 - val_mae: 0.4488 - learning_rate: 0.0050
# Epoch 145/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2691 - mae: 0.4165 - val_loss: 0.3306 - val_mae: 0.4491 - learning_rate: 0.0050
# Epoch 146/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2689 - mae: 0.4163 - val_loss: 0.3301 - val_mae: 0.4488 - learning_rate: 0.0050
# Epoch 147/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2689 - mae: 0.4163 - val_loss: 0.3308 - val_mae: 0.4492 - learning_rate: 0.0050
# Epoch 148/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2686 - mae: 0.4162 - val_loss: 0.3300 - val_mae: 0.4488 - learning_rate: 0.0050
# Epoch 149/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2687 - mae: 0.4162 - val_loss: 0.3306 - val_mae: 0.4491 - learning_rate: 0.0050
# Epoch 150/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2682 - mae: 0.4159 - val_loss: 0.3300 - val_mae: 0.4489 - learning_rate: 0.0050
# Epoch 151/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2683 - mae: 0.4159 - val_loss: 0.3300 - val_mae: 0.4489 - learning_rate: 0.0050
# Epoch 152/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2681 - mae: 0.4159 - val_loss: 0.3295 - val_mae: 0.4488 - learning_rate: 0.0050
# Epoch 153/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2683 - mae: 0.4160 - val_loss: 0.3296 - val_mae: 0.4488 - learning_rate: 0.0050
# Epoch 154/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2679 - mae: 0.4157 - val_loss: 0.3294 - val_mae: 0.4485 - learning_rate: 0.0050
# Epoch 155/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2685 - mae: 0.4162 - val_loss: 0.3290 - val_mae: 0.4484 - learning_rate: 0.0050
# Epoch 156/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2679 - mae: 0.4157 - val_loss: 0.3296 - val_mae: 0.4487 - learning_rate: 0.0050
# Epoch 157/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2682 - mae: 0.4161 - val_loss: 0.3290 - val_mae: 0.4483 - learning_rate: 0.0050
# Epoch 158/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2681 - mae: 0.4158 - val_loss: 0.3292 - val_mae: 0.4484 - learning_rate: 0.0050
# Epoch 159/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2679 - mae: 0.4157 - val_loss: 0.3292 - val_mae: 0.4485 - learning_rate: 0.0050
# Epoch 160/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.2680 - mae: 0.4158 - val_loss: 0.3292 - val_mae: 0.4483 - learning_rate: 0.0050
# Epoch 161/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2683 - mae: 0.4160 - val_loss: 0.3289 - val_mae: 0.4481 - learning_rate: 0.0050
# Epoch 162/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2679 - mae: 0.4156 - val_loss: 0.3293 - val_mae: 0.4485 - learning_rate: 0.0050
# Epoch 163/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2680 - mae: 0.4158 - val_loss: 0.3294 - val_mae: 0.4483 - learning_rate: 0.0050
# Epoch 164/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2682 - mae: 0.4160 - val_loss: 0.3287 - val_mae: 0.4480 - learning_rate: 0.0050
# Epoch 165/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2679 - mae: 0.4156 - val_loss: 0.3292 - val_mae: 0.4482 - learning_rate: 0.0050
# Epoch 166/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2678 - mae: 0.4157 - val_loss: 0.3286 - val_mae: 0.4479 - learning_rate: 0.0050
# Epoch 167/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2679 - mae: 0.4157 - val_loss: 0.3295 - val_mae: 0.4483 - learning_rate: 0.0050
# Epoch 168/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2679 - mae: 0.4157 - val_loss: 0.3286 - val_mae: 0.4477 - learning_rate: 0.0050
# Epoch 169/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2681 - mae: 0.4157 - val_loss: 0.3282 - val_mae: 0.4474 - learning_rate: 0.0050
# Epoch 170/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2678 - mae: 0.4156 - val_loss: 0.3289 - val_mae: 0.4479 - learning_rate: 0.0050
# Epoch 171/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2679 - mae: 0.4157 - val_loss: 0.3293 - val_mae: 0.4480 - learning_rate: 0.0050
# Epoch 172/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.2676 - mae: 0.4155 - val_loss: 0.3290 - val_mae: 0.4479 - learning_rate: 0.0050
# Epoch 173/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2680 - mae: 0.4158 - val_loss: 0.3289 - val_mae: 0.4476 - learning_rate: 0.0050
# Epoch 174/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.2678 - mae: 0.4156 - val_loss: 0.3285 - val_mae: 0.4474 - learning_rate: 0.0050
# Epoch 175/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.2676 - mae: 0.4154 - val_loss: 0.3291 - val_mae: 0.4478 - learning_rate: 0.0050
# Epoch 176/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.2677 - mae: 0.4154 - val_loss: 0.3292 - val_mae: 0.4479 - learning_rate: 0.0050
# Epoch 177/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.2677 - mae: 0.4155 - val_loss: 0.3286 - val_mae: 0.4475 - learning_rate: 0.0050
# Epoch 178/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.2675 - mae: 0.4153 - val_loss: 0.3289 - val_mae: 0.4477 - learning_rate: 0.0050
# Epoch 179/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.2677 - mae: 0.4154 - val_loss: 0.3285 - val_mae: 0.4475 - learning_rate: 0.0050
# Epoch 180/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.2674 - mae: 0.4152 - val_loss: 0.3286 - val_mae: 0.4474 - learning_rate: 0.0050
# Epoch 181/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.2675 - mae: 0.4152 - val_loss: 0.3289 - val_mae: 0.4477 - learning_rate: 0.0050
# Epoch 182/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2675 - mae: 0.4153 - val_loss: 0.3284 - val_mae: 0.4473 - learning_rate: 0.0050
# Epoch 183/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2672 - mae: 0.4150 - val_loss: 0.3290 - val_mae: 0.4479 - learning_rate: 0.0050
# Epoch 184/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2672 - mae: 0.4150 - val_loss: 0.3289 - val_mae: 0.4475 - learning_rate: 0.0050
# Epoch 185/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2674 - mae: 0.4153 - val_loss: 0.3285 - val_mae: 0.4474 - learning_rate: 0.0050
# Epoch 186/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2672 - mae: 0.4149 - val_loss: 0.3290 - val_mae: 0.4476 - learning_rate: 0.0050
# Epoch 187/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2673 - mae: 0.4150 - val_loss: 0.3286 - val_mae: 0.4474 - learning_rate: 0.0050
# Epoch 188/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2671 - mae: 0.4148 - val_loss: 0.3282 - val_mae: 0.4472 - learning_rate: 0.0050
# Epoch 189/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2671 - mae: 0.4149 - val_loss: 0.3284 - val_mae: 0.4472 - learning_rate: 0.0050
# Epoch 190/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2609 - mae: 0.4096 - val_loss: 0.3271 - val_mae: 0.4450 - learning_rate: 0.0025
# Epoch 191/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2570 - mae: 0.4063 - val_loss: 0.3284 - val_mae: 0.4479 - learning_rate: 0.0025
# Epoch 192/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2556 - mae: 0.4063 - val_loss: 0.3267 - val_mae: 0.4459 - learning_rate: 0.0025
# Epoch 193/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.2565 - mae: 0.4066 - val_loss: 0.3265 - val_mae: 0.4459 - learning_rate: 0.0025
# Epoch 194/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2561 - mae: 0.4062 - val_loss: 0.3260 - val_mae: 0.4458 - learning_rate: 0.0025
# Epoch 195/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2562 - mae: 0.4062 - val_loss: 0.3264 - val_mae: 0.4461 - learning_rate: 0.0025
# Epoch 196/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2561 - mae: 0.4061 - val_loss: 0.3263 - val_mae: 0.4457 - learning_rate: 0.0025
# Epoch 197/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2562 - mae: 0.4062 - val_loss: 0.3263 - val_mae: 0.4459 - learning_rate: 0.0025
# Epoch 198/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.2562 - mae: 0.4062 - val_loss: 0.3262 - val_mae: 0.4457 - learning_rate: 0.0025
# Epoch 199/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2562 - mae: 0.4062 - val_loss: 0.3267 - val_mae: 0.4460 - learning_rate: 0.0025
# Epoch 200/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.2560 - mae: 0.4061 - val_loss: 0.3264 - val_mae: 0.4458 - learning_rate: 0.0025
# Epoch 201/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2563 - mae: 0.4063 - val_loss: 0.3260 - val_mae: 0.4457 - learning_rate: 0.0025
# Epoch 202/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.2560 - mae: 0.4060 - val_loss: 0.3262 - val_mae: 0.4456 - learning_rate: 0.0025
# Epoch 203/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2562 - mae: 0.4061 - val_loss: 0.3265 - val_mae: 0.4458 - learning_rate: 0.0025
# Epoch 204/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2559 - mae: 0.4060 - val_loss: 0.3262 - val_mae: 0.4456 - learning_rate: 0.0025
# Epoch 205/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2562 - mae: 0.4062 - val_loss: 0.3260 - val_mae: 0.4455 - learning_rate: 0.0025
# Epoch 206/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.2558 - mae: 0.4058 - val_loss: 0.3262 - val_mae: 0.4456 - learning_rate: 0.0025
# Epoch 207/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2560 - mae: 0.4060 - val_loss: 0.3263 - val_mae: 0.4455 - learning_rate: 0.0025
# Epoch 208/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2558 - mae: 0.4059 - val_loss: 0.3263 - val_mae: 0.4457 - learning_rate: 0.0025
# Epoch 209/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2559 - mae: 0.4059 - val_loss: 0.3265 - val_mae: 0.4457 - learning_rate: 0.0025
# Epoch 210/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2559 - mae: 0.4060 - val_loss: 0.3258 - val_mae: 0.4452 - learning_rate: 0.0025
# Epoch 211/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2559 - mae: 0.4059 - val_loss: 0.3264 - val_mae: 0.4455 - learning_rate: 0.0025
# Epoch 212/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2559 - mae: 0.4059 - val_loss: 0.3265 - val_mae: 0.4457 - learning_rate: 0.0025
# Epoch 213/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2559 - mae: 0.4059 - val_loss: 0.3260 - val_mae: 0.4454 - learning_rate: 0.0025
# Epoch 214/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2557 - mae: 0.4058 - val_loss: 0.3260 - val_mae: 0.4455 - learning_rate: 0.0025
# Epoch 215/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.2559 - mae: 0.4059 - val_loss: 0.3259 - val_mae: 0.4453 - learning_rate: 0.0025
# Epoch 216/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2558 - mae: 0.4058 - val_loss: 0.3258 - val_mae: 0.4452 - learning_rate: 0.0025
# Epoch 217/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2559 - mae: 0.4058 - val_loss: 0.3255 - val_mae: 0.4452 - learning_rate: 0.0025
# Epoch 218/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2557 - mae: 0.4057 - val_loss: 0.3256 - val_mae: 0.4452 - learning_rate: 0.0025
# Epoch 219/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.2559 - mae: 0.4058 - val_loss: 0.3256 - val_mae: 0.4451 - learning_rate: 0.0025
# Epoch 220/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2559 - mae: 0.4059 - val_loss: 0.3256 - val_mae: 0.4452 - learning_rate: 0.0025
# Epoch 221/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.2558 - mae: 0.4058 - val_loss: 0.3254 - val_mae: 0.4451 - learning_rate: 0.0025
# Epoch 222/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.2559 - mae: 0.4059 - val_loss: 0.3252 - val_mae: 0.4449 - learning_rate: 0.0025
# Epoch 223/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.2559 - mae: 0.4058 - val_loss: 0.3251 - val_mae: 0.4448 - learning_rate: 0.0025
# Epoch 224/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2559 - mae: 0.4058 - val_loss: 0.3256 - val_mae: 0.4452 - learning_rate: 0.0025
# Epoch 225/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2559 - mae: 0.4059 - val_loss: 0.3249 - val_mae: 0.4448 - learning_rate: 0.0025
# Epoch 226/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.2559 - mae: 0.4058 - val_loss: 0.3251 - val_mae: 0.4448 - learning_rate: 0.0025
# Epoch 227/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2559 - mae: 0.4058 - val_loss: 0.3247 - val_mae: 0.4446 - learning_rate: 0.0025
# Epoch 228/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2558 - mae: 0.4057 - val_loss: 0.3252 - val_mae: 0.4450 - learning_rate: 0.0025
# Epoch 229/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2560 - mae: 0.4059 - val_loss: 0.3249 - val_mae: 0.4447 - learning_rate: 0.0025
# Epoch 230/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2558 - mae: 0.4057 - val_loss: 0.3249 - val_mae: 0.4447 - learning_rate: 0.0025
# Epoch 231/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2559 - mae: 0.4058 - val_loss: 0.3248 - val_mae: 0.4447 - learning_rate: 0.0025
# Epoch 232/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2560 - mae: 0.4059 - val_loss: 0.3246 - val_mae: 0.4446 - learning_rate: 0.0025
# Epoch 233/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2557 - mae: 0.4057 - val_loss: 0.3249 - val_mae: 0.4448 - learning_rate: 0.0025
# Epoch 234/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2559 - mae: 0.4059 - val_loss: 0.3245 - val_mae: 0.4444 - learning_rate: 0.0025
# Epoch 235/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2558 - mae: 0.4058 - val_loss: 0.3245 - val_mae: 0.4445 - learning_rate: 0.0025
# Epoch 236/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2560 - mae: 0.4059 - val_loss: 0.3247 - val_mae: 0.4445 - learning_rate: 0.0025
# Epoch 237/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2558 - mae: 0.4058 - val_loss: 0.3248 - val_mae: 0.4447 - learning_rate: 0.0025
# Epoch 238/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2560 - mae: 0.4058 - val_loss: 0.3244 - val_mae: 0.4444 - learning_rate: 0.0025
# Epoch 239/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.2558 - mae: 0.4057 - val_loss: 0.3247 - val_mae: 0.4448 - learning_rate: 0.0025
# Epoch 240/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2559 - mae: 0.4059 - val_loss: 0.3245 - val_mae: 0.4444 - learning_rate: 0.0025
# Epoch 241/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2558 - mae: 0.4058 - val_loss: 0.3244 - val_mae: 0.4444 - learning_rate: 0.0025
# Epoch 242/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2558 - mae: 0.4058 - val_loss: 0.3239 - val_mae: 0.4440 - learning_rate: 0.0025
# Epoch 243/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2558 - mae: 0.4057 - val_loss: 0.3244 - val_mae: 0.4446 - learning_rate: 0.0025
# Epoch 244/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2558 - mae: 0.4057 - val_loss: 0.3248 - val_mae: 0.4446 - learning_rate: 0.0025
# Epoch 245/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.2559 - mae: 0.4058 - val_loss: 0.3243 - val_mae: 0.4443 - learning_rate: 0.0025
# Epoch 246/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2559 - mae: 0.4058 - val_loss: 0.3244 - val_mae: 0.4443 - learning_rate: 0.0025
# Epoch 247/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2557 - mae: 0.4057 - val_loss: 0.3239 - val_mae: 0.4441 - learning_rate: 0.0025
# Epoch 248/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2559 - mae: 0.4058 - val_loss: 0.3239 - val_mae: 0.4442 - learning_rate: 0.0025
# Epoch 249/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2557 - mae: 0.4056 - val_loss: 0.3242 - val_mae: 0.4444 - learning_rate: 0.0025
# Epoch 250/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2558 - mae: 0.4057 - val_loss: 0.3240 - val_mae: 0.4441 - learning_rate: 0.0025
# Epoch 251/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2557 - mae: 0.4056 - val_loss: 0.3240 - val_mae: 0.4442 - learning_rate: 0.0025
# Epoch 252/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2558 - mae: 0.4057 - val_loss: 0.3241 - val_mae: 0.4441 - learning_rate: 0.0025
# Epoch 253/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2558 - mae: 0.4057 - val_loss: 0.3241 - val_mae: 0.4443 - learning_rate: 0.0025
# Epoch 254/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2557 - mae: 0.4056 - val_loss: 0.3240 - val_mae: 0.4442 - learning_rate: 0.0025
# Epoch 255/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2558 - mae: 0.4058 - val_loss: 0.3242 - val_mae: 0.4442 - learning_rate: 0.0025
# Epoch 256/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2556 - mae: 0.4057 - val_loss: 0.3238 - val_mae: 0.4440 - learning_rate: 0.0025
# Epoch 257/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.2558 - mae: 0.4058 - val_loss: 0.3240 - val_mae: 0.4443 - learning_rate: 0.0025
# Epoch 258/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2556 - mae: 0.4056 - val_loss: 0.3237 - val_mae: 0.4439 - learning_rate: 0.0025
# Epoch 259/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2556 - mae: 0.4056 - val_loss: 0.3242 - val_mae: 0.4442 - learning_rate: 0.0025
# Epoch 260/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.2556 - mae: 0.4057 - val_loss: 0.3237 - val_mae: 0.4438 - learning_rate: 0.0025
# Epoch 261/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.2558 - mae: 0.4058 - val_loss: 0.3233 - val_mae: 0.4438 - learning_rate: 0.0025
# Epoch 262/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.2554 - mae: 0.4055 - val_loss: 0.3238 - val_mae: 0.4440 - learning_rate: 0.0025
# Epoch 263/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.2558 - mae: 0.4058 - val_loss: 0.3239 - val_mae: 0.4439 - learning_rate: 0.0025
# Epoch 264/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2557 - mae: 0.4057 - val_loss: 0.3235 - val_mae: 0.4438 - learning_rate: 0.0025
# Epoch 265/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2555 - mae: 0.4056 - val_loss: 0.3238 - val_mae: 0.4440 - learning_rate: 0.0025
# Epoch 266/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2556 - mae: 0.4057 - val_loss: 0.3236 - val_mae: 0.4438 - learning_rate: 0.0025
# Epoch 267/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2556 - mae: 0.4056 - val_loss: 0.3235 - val_mae: 0.4436 - learning_rate: 0.0025
# Epoch 268/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.2555 - mae: 0.4056 - val_loss: 0.3238 - val_mae: 0.4438 - learning_rate: 0.0025
# Epoch 269/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2554 - mae: 0.4055 - val_loss: 0.3236 - val_mae: 0.4438 - learning_rate: 0.0025
# Epoch 270/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.2557 - mae: 0.4057 - val_loss: 0.3236 - val_mae: 0.4438 - learning_rate: 0.0025
# Epoch 271/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2554 - mae: 0.4055 - val_loss: 0.3236 - val_mae: 0.4436 - learning_rate: 0.0025
# Epoch 272/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2554 - mae: 0.4055 - val_loss: 0.3234 - val_mae: 0.4436 - learning_rate: 0.0025
# Epoch 273/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2556 - mae: 0.4057 - val_loss: 0.3242 - val_mae: 0.4439 - learning_rate: 0.0025
# Epoch 274/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2554 - mae: 0.4056 - val_loss: 0.3234 - val_mae: 0.4437 - learning_rate: 0.0025
# Epoch 275/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.2554 - mae: 0.4056 - val_loss: 0.3229 - val_mae: 0.4434 - learning_rate: 0.0025
# Epoch 276/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.2555 - mae: 0.4056 - val_loss: 0.3238 - val_mae: 0.4436 - learning_rate: 0.0025
# Epoch 277/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2555 - mae: 0.4056 - val_loss: 0.3235 - val_mae: 0.4437 - learning_rate: 0.0025
# Epoch 278/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2553 - mae: 0.4055 - val_loss: 0.3233 - val_mae: 0.4436 - learning_rate: 0.0025
# Epoch 279/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.2552 - mae: 0.4054 - val_loss: 0.3235 - val_mae: 0.4436 - learning_rate: 0.0025
# Epoch 280/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2556 - mae: 0.4057 - val_loss: 0.3235 - val_mae: 0.4434 - learning_rate: 0.0025
# Epoch 281/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2553 - mae: 0.4055 - val_loss: 0.3231 - val_mae: 0.4435 - learning_rate: 0.0025
# Epoch 282/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2553 - mae: 0.4055 - val_loss: 0.3232 - val_mae: 0.4435 - learning_rate: 0.0025
# Epoch 283/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2552 - mae: 0.4054 - val_loss: 0.3233 - val_mae: 0.4434 - learning_rate: 0.0025
# Epoch 284/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2554 - mae: 0.4056 - val_loss: 0.3227 - val_mae: 0.4430 - learning_rate: 0.0025
# Epoch 285/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2553 - mae: 0.4054 - val_loss: 0.3229 - val_mae: 0.4434 - learning_rate: 0.0025
# Epoch 286/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.2552 - mae: 0.4054 - val_loss: 0.3232 - val_mae: 0.4433 - learning_rate: 0.0025
# Epoch 287/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2553 - mae: 0.4055 - val_loss: 0.3232 - val_mae: 0.4433 - learning_rate: 0.0025
# Epoch 288/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.2552 - mae: 0.4053 - val_loss: 0.3228 - val_mae: 0.4432 - learning_rate: 0.0025
# Epoch 289/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2554 - mae: 0.4056 - val_loss: 0.3233 - val_mae: 0.4434 - learning_rate: 0.0025
# Epoch 290/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.2549 - mae: 0.4052 - val_loss: 0.3230 - val_mae: 0.4432 - learning_rate: 0.0025
# Epoch 291/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2553 - mae: 0.4055 - val_loss: 0.3228 - val_mae: 0.4431 - learning_rate: 0.0025
# Epoch 292/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.2551 - mae: 0.4053 - val_loss: 0.3227 - val_mae: 0.4431 - learning_rate: 0.0025
# Epoch 293/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2552 - mae: 0.4054 - val_loss: 0.3226 - val_mae: 0.4429 - learning_rate: 0.0025
# Epoch 294/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.2550 - mae: 0.4052 - val_loss: 0.3226 - val_mae: 0.4429 - learning_rate: 0.0025
# Epoch 295/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2553 - mae: 0.4055 - val_loss: 0.3230 - val_mae: 0.4431 - learning_rate: 0.0025
# Epoch 296/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2550 - mae: 0.4052 - val_loss: 0.3224 - val_mae: 0.4429 - learning_rate: 0.0025
# Epoch 297/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2552 - mae: 0.4054 - val_loss: 0.3228 - val_mae: 0.4431 - learning_rate: 0.0025
# Epoch 298/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2551 - mae: 0.4052 - val_loss: 0.3227 - val_mae: 0.4430 - learning_rate: 0.0025
# Epoch 299/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2550 - mae: 0.4053 - val_loss: 0.3223 - val_mae: 0.4430 - learning_rate: 0.0025
# Epoch 300/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.2549 - mae: 0.4052 - val_loss: 0.3227 - val_mae: 0.4430 - learning_rate: 0.0025
# Epoch 301/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.2552 - mae: 0.4054 - val_loss: 0.3225 - val_mae: 0.4428 - learning_rate: 0.0025
# Epoch 302/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.2551 - mae: 0.4053 - val_loss: 0.3228 - val_mae: 0.4431 - learning_rate: 0.0025
# Epoch 303/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.2549 - mae: 0.4052 - val_loss: 0.3224 - val_mae: 0.4429 - learning_rate: 0.0025
# Epoch 304/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2553 - mae: 0.4055 - val_loss: 0.3227 - val_mae: 0.4429 - learning_rate: 0.0025
# Epoch 305/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2550 - mae: 0.4052 - val_loss: 0.3227 - val_mae: 0.4431 - learning_rate: 0.0025
# Epoch 306/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2551 - mae: 0.4054 - val_loss: 0.3224 - val_mae: 0.4428 - learning_rate: 0.0025
# Epoch 307/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2551 - mae: 0.4053 - val_loss: 0.3227 - val_mae: 0.4430 - learning_rate: 0.0025
# Epoch 308/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2550 - mae: 0.4053 - val_loss: 0.3223 - val_mae: 0.4428 - learning_rate: 0.0025
# Epoch 309/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2552 - mae: 0.4054 - val_loss: 0.3227 - val_mae: 0.4431 - learning_rate: 0.0025
# Epoch 310/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.2547 - mae: 0.4051 - val_loss: 0.3225 - val_mae: 0.4429 - learning_rate: 0.0025
# Epoch 311/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2552 - mae: 0.4055 - val_loss: 0.3227 - val_mae: 0.4431 - learning_rate: 0.0025
# Epoch 312/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2549 - mae: 0.4052 - val_loss: 0.3225 - val_mae: 0.4429 - learning_rate: 0.0025
# Epoch 313/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2550 - mae: 0.4052 - val_loss: 0.3225 - val_mae: 0.4429 - learning_rate: 0.0025
# Epoch 314/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2551 - mae: 0.4053 - val_loss: 0.3227 - val_mae: 0.4430 - learning_rate: 0.0025
# Epoch 315/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.2549 - mae: 0.4051 - val_loss: 0.3226 - val_mae: 0.4431 - learning_rate: 0.0025
# Epoch 316/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2549 - mae: 0.4052 - val_loss: 0.3225 - val_mae: 0.4430 - learning_rate: 0.0025
# Epoch 317/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2550 - mae: 0.4053 - val_loss: 0.3230 - val_mae: 0.4431 - learning_rate: 0.0025
# Epoch 318/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.2549 - mae: 0.4052 - val_loss: 0.3230 - val_mae: 0.4433 - learning_rate: 0.0025
# Epoch 319/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2551 - mae: 0.4053 - val_loss: 0.3225 - val_mae: 0.4430 - learning_rate: 0.0025
# Epoch 320/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.2550 - mae: 0.4053 - val_loss: 0.3229 - val_mae: 0.4431 - learning_rate: 0.0025
# Epoch 321/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.2549 - mae: 0.4051 - val_loss: 0.3232 - val_mae: 0.4435 - learning_rate: 0.0025
# Epoch 322/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.2550 - mae: 0.4052 - val_loss: 0.3227 - val_mae: 0.4431 - learning_rate: 0.0025
# Epoch 323/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2549 - mae: 0.4052 - val_loss: 0.3229 - val_mae: 0.4432 - learning_rate: 0.0025
# Epoch 324/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.2549 - mae: 0.4052 - val_loss: 0.3225 - val_mae: 0.4430 - learning_rate: 0.0025
# Epoch 325/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2547 - mae: 0.4050 - val_loss: 0.3231 - val_mae: 0.4432 - learning_rate: 0.0025
# Epoch 326/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2551 - mae: 0.4053 - val_loss: 0.3231 - val_mae: 0.4433 - learning_rate: 0.0025
# Epoch 327/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2547 - mae: 0.4051 - val_loss: 0.3228 - val_mae: 0.4432 - learning_rate: 0.0025
# Epoch 328/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2550 - mae: 0.4053 - val_loss: 0.3229 - val_mae: 0.4431 - learning_rate: 0.0025
# Epoch 329/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2525 - mae: 0.4030 - val_loss: 0.3241 - val_mae: 0.4458 - learning_rate: 0.0012
# Epoch 330/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2510 - mae: 0.4024 - val_loss: 0.3231 - val_mae: 0.4439 - learning_rate: 0.0012
# Epoch 331/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.2510 - mae: 0.4021 - val_loss: 0.3234 - val_mae: 0.4447 - learning_rate: 0.0012
# Epoch 332/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.2510 - mae: 0.4023 - val_loss: 0.3232 - val_mae: 0.4443 - learning_rate: 0.0012
# Epoch 333/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2511 - mae: 0.4023 - val_loss: 0.3233 - val_mae: 0.4444 - learning_rate: 0.0012
# Epoch 334/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2511 - mae: 0.4023 - val_loss: 0.3235 - val_mae: 0.4446 - learning_rate: 0.0012
# Epoch 335/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.2509 - mae: 0.4022 - val_loss: 0.3234 - val_mae: 0.4443 - learning_rate: 0.0012
# Epoch 336/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.2510 - mae: 0.4022 - val_loss: 0.3231 - val_mae: 0.4443 - learning_rate: 0.0012
# Epoch 337/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.2511 - mae: 0.4023 - val_loss: 0.3233 - val_mae: 0.4443 - learning_rate: 0.0012
# Epoch 338/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.2509 - mae: 0.4021 - val_loss: 0.3231 - val_mae: 0.4442 - learning_rate: 0.0012
# Epoch 339/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.2511 - mae: 0.4023 - val_loss: 0.3232 - val_mae: 0.4443 - learning_rate: 0.0012
# Epoch 340/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.2510 - mae: 0.4023 - val_loss: 0.3229 - val_mae: 0.4441 - learning_rate: 0.0012
# Epoch 341/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.2510 - mae: 0.4022 - val_loss: 0.3232 - val_mae: 0.4443 - learning_rate: 0.0012
# Epoch 342/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2509 - mae: 0.4022 - val_loss: 0.3229 - val_mae: 0.4439 - learning_rate: 0.0012
# Epoch 343/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2510 - mae: 0.4022 - val_loss: 0.3230 - val_mae: 0.4443 - learning_rate: 0.0012
# Epoch 344/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2510 - mae: 0.4022 - val_loss: 0.3229 - val_mae: 0.4440 - learning_rate: 0.0012
# Epoch 345/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2509 - mae: 0.4021 - val_loss: 0.3230 - val_mae: 0.4442 - learning_rate: 0.0012
# Epoch 346/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2510 - mae: 0.4022 - val_loss: 0.3230 - val_mae: 0.4441 - learning_rate: 0.0012
# Epoch 347/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2510 - mae: 0.4022 - val_loss: 0.3229 - val_mae: 0.4441 - learning_rate: 0.0012
# Epoch 348/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2509 - mae: 0.4021 - val_loss: 0.3229 - val_mae: 0.4442 - learning_rate: 0.0012
# Epoch 349/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2501 - mae: 0.4013 - val_loss: 0.3234 - val_mae: 0.4451 - learning_rate: 6.2500e-04
# Epoch 350/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2498 - mae: 0.4013 - val_loss: 0.3231 - val_mae: 0.4446 - learning_rate: 6.2500e-04
# Epoch 351/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2497 - mae: 0.4010 - val_loss: 0.3231 - val_mae: 0.4446 - learning_rate: 6.2500e-04
# Epoch 352/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2497 - mae: 0.4011 - val_loss: 0.3231 - val_mae: 0.4447 - learning_rate: 6.2500e-04
# Epoch 353/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2496 - mae: 0.4010 - val_loss: 0.3230 - val_mae: 0.4445 - learning_rate: 6.2500e-04
# Epoch 354/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2496 - mae: 0.4010 - val_loss: 0.3229 - val_mae: 0.4445 - learning_rate: 6.2500e-04
# Epoch 355/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2497 - mae: 0.4010 - val_loss: 0.3229 - val_mae: 0.4446 - learning_rate: 6.2500e-04
# Epoch 356/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2497 - mae: 0.4010 - val_loss: 0.3229 - val_mae: 0.4446 - learning_rate: 6.2500e-04
# Epoch 357/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2496 - mae: 0.4010 - val_loss: 0.3228 - val_mae: 0.4444 - learning_rate: 6.2500e-04
# Epoch 358/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2496 - mae: 0.4010 - val_loss: 0.3229 - val_mae: 0.4446 - learning_rate: 6.2500e-04
# Training completed in 109.66 seconds

# %% [markdown]
# ## Model Evaluation and Visualization
# With our model built using TensorFlow’s high-level Keras API, we’ll now evaluate its performance on the test data.
# We'll also generate visualizations to:
#
# Display the training loss curve over epochs
#
# Compare predicted vs actual values to assess accuracy
#
# Gain visual insights into how well the model has learned the non-linear function
#
# These evaluations help validate the model’s effectiveness and identify any areas for improvement.

# %%
# Plot training and validation loss
plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('MSE Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.grid(True)
plt.show()

# Plot MAE metric
plt.figure(figsize=(10, 6))
plt.plot(history.history['mae'], label='Training MAE')
plt.plot(history.history['val_mae'], label='Validation MAE')
plt.xlabel('Epochs')
plt.ylabel('Mean Absolute Error')
plt.title('Training and Validation MAE')
plt.legend()
plt.grid(True)
plt.show()

# Evaluate on test set
test_results = model.evaluate(X_test, y_test, verbose=1)
print(f"Test Loss (MSE): {test_results[0]:.6f}")
print(f"Test MAE: {test_results[1]:.6f}")

# Get predictions
y_pred_test = model.predict(X_test)

# Visualize predictions vs actual values
plt.figure(figsize=(10, 6))
plt.scatter(y_test.numpy(), y_pred_test, alpha=0.5)
plt.plot([-5, 5], [-5, 5], 'r--')  # Perfect prediction line
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.title('Predictions vs Actual Values')
plt.grid(True)
plt.show()

# Create a 4D visualization (3D plot with color as the 4th dimension)
def visualize_4d(X, y_true, y_pred, title):
    # Convert tensors to numpy
    X_np = X.numpy()
    y_true_np = y_true.numpy().flatten()
    y_pred_np = y_pred.flatten()

    # Create a 3D scatter plot with color as the 4th dimension
    fig = plt.figure(figsize=(12, 10))
    ax = fig.add_subplot(111, projection='3d')

    # Calculate prediction error for coloring
    error = y_true_np - y_pred_np

    # Create the scatter plot
    scatter = ax.scatter(X_np[:, 0], X_np[:, 1], X_np[:, 2],
                          c=error,  # Use error for coloring
                          cmap=cm.coolwarm,
                          marker='o',
                          alpha=0.7,
                          s=30)

    # Add a color bar
    cbar = plt.colorbar(scatter)
    cbar.set_label('Prediction Error')

    # Set labels and title
    ax.set_xlabel('X1')
    ax.set_ylabel('X2')
    ax.set_zlabel('X3')
    ax.set_title(title)

    # Show the plot
    plt.show()

# Generate sample data points for visualization
X_vis, y_vis = generate_data(200)

# Get predictions for visualization
y_vis_pred = model.predict(X_vis)

# Create 4D visualization
visualize_4d(X_vis, y_vis, y_vis_pred, '4D Visualization of Model Predictions vs Actual Values')

# Generate and plot 2D slices
def plot_2d_slices(X_range=2.0, grid_points=20):
    # Create a grid of points for visualization
    x1 = np.linspace(-X_range, X_range, grid_points)
    x2 = np.linspace(-X_range, X_range, grid_points)
    x3_values = [-1.5, 0, 1.5]  # Three fixed values for x3

    fig, axes = plt.subplots(1, len(x3_values), figsize=(18, 5))

    for i, x3 in enumerate(x3_values):
        # Create meshgrid for x1 and x2
        X1, X2 = np.meshgrid(x1, x2)

        # Create input data with fixed x3
        X_input_np = np.zeros((grid_points*grid_points, 3))
        X_input_np[:, 0] = X1.flatten()
        X_input_np[:, 1] = X2.flatten()
        X_input_np[:, 2] = x3

        # Convert to tensor
        X_input = tf.convert_to_tensor(X_input_np, dtype=tf.float32)

        # Get true values and predictions
        y_true = true_function(X_input).numpy().reshape(grid_points, grid_points)
        y_pred = model.predict(X_input).reshape(grid_points, grid_points)

        # Plot the true function
        im1 = axes[i].contourf(X1, X2, y_true, cmap='viridis', levels=20)
        axes[i].set_title(f'True Function (x3={x3})')
        axes[i].set_xlabel('X1')
        axes[i].set_ylabel('X2')

        # Add a colorbar
        plt.colorbar(im1, ax=axes[i])

    plt.tight_layout()
    plt.show()

    # Now plot the predicted function
    fig, axes = plt.subplots(1, len(x3_values), figsize=(18, 5))

    for i, x3 in enumerate(x3_values):
        # Create meshgrid for x1 and x2
        X1, X2 = np.meshgrid(x1, x2)

        # Create input data with fixed x3
        X_input_np = np.zeros((grid_points*grid_points, 3))
        X_input_np[:, 0] = X1.flatten()
        X_input_np[:, 1] = X2.flatten()
        X_input_np[:, 2] = x3

        # Convert to tensor
        X_input = tf.convert_to_tensor(X_input_np, dtype=tf.float32)

        # Get true values and predictions
        y_true = true_function(X_input).numpy().reshape(grid_points, grid_points)
        y_pred = model.predict(X_input).reshape(grid_points, grid_points)

        # Plot the predicted function
        im2 = axes[i].contourf(X1, X2, y_pred, cmap='viridis', levels=20)
        axes[i].set_title(f'Neural Network Prediction (x3={x3})')
        axes[i].set_xlabel('X1')
        axes[i].set_ylabel('X2')

        # Add a colorbar
        plt.colorbar(im2, ax=axes[i])

    plt.tight_layout()
    plt.show()

# Generate and plot 2D slices
plot_2d_slices(X_range=2.0, grid_points=20)
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2827 - mae: 0.4167
# Test Loss (MSE): 0.322263
# Test MAE: 0.442790
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
